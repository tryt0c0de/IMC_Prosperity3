# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"8cf4dead-dd7a-4882-8510-bbce815a8c28.csv",sep = ";")

# %%
data
# Out:
#       day  timestamp           product  bid_price_1  bid_volume_1  \
# 0      -1          0  RAINFOREST_RESIN        10002             1
# 1      -1          0              KELP         2028             1
# 2      -1        100              KELP         2025            24
# 3      -1        100  RAINFOREST_RESIN         9996             2
# 4      -1        200  RAINFOREST_RESIN         9995            20
# ...   ...        ...               ...          ...           ...
# 3995   -1     199700              KELP         2020            27
# 3996   -1     199800  RAINFOREST_RESIN         9995            21
# 3997   -1     199800              KELP         2020            21
# 3998   -1     199900              KELP         2020            32
# 3999   -1     199900  RAINFOREST_RESIN         9996             2
#
#       bid_price_2  bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  \
# 0          9996.0           2.0       9995.0          29.0        10004
# ...

# %%
#Split the data into product = "RAINFOREST_RESIN" and product = "KELP"
rainforest_resin = data[data['product'] == "RAINFOREST_RESIN"]
kelp = data[data['product'] == "KELP"]

#Plot the data
plt.plot(rainforest_resin['timestamp'], rainforest_resin['bid_price_1'],"x")

# %%
list(kelp["profit_and_loss"])[-1] + list(rainforest_resin["profit_and_loss"])[-1]
# Out:
# 288.3515625

# %%
plt.plot(kelp['timestamp'], kelp['bid_price_1'],".")
